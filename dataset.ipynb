# %%
import pandas as pd
import os

# %%
data = pd.read_csv('csv\styles.csv', on_bad_lines='skip')
data
# Out:
#           id gender masterCategory subCategory            articleType  \
# 0      15970    Men        Apparel     Topwear                 Shirts
# 1      39386    Men        Apparel  Bottomwear                  Jeans
# 2      59263  Women    Accessories     Watches                Watches
# 3      21379    Men        Apparel  Bottomwear            Track Pants
# 4      53759    Men        Apparel     Topwear                Tshirts
# ...      ...    ...            ...         ...                    ...
# 44419  17036    Men       Footwear       Shoes           Casual Shoes
# 44420   6461    Men       Footwear  Flip Flops             Flip Flops
# 44421  18842    Men        Apparel     Topwear                Tshirts
# 44422  46694  Women  Personal Care   Fragrance  Perfume and Body Mist
# 44423  51623  Women    Accessories     Watches                Watches
#
#       baseColour  season    year   usage  \
# 0      Navy Blue    Fall  2011.0  Casual
# ...

# %%
data.drop(['gender', 'masterCategory', 'articleType', 'baseColour', 
           'season', 'year', 'usage', 'productDisplayName'], axis=1, inplace=True)
for category in data['subCategory']:
  if category not in ['Topwear', 'Bottomwear']:
    data.drop(data[data['subCategory'] == category].index, inplace=True)
data
# Out:
#           id subCategory
# 0      15970     Topwear
# 1      39386  Bottomwear
# 3      21379  Bottomwear
# 4      53759     Topwear
# 5       1855     Topwear
# ...      ...         ...
# 44414  30614     Topwear
# 44415  13496     Topwear
# 44417  12544     Topwear
# 44418  42234     Topwear
# 44421  18842     Topwear
#
# [18096 rows x 2 columns]

# %%
images = pd.read_csv('csv\images.csv', on_bad_lines='skip')
images.head()
for i in range(len(images)):
  if int(images['filename'][i][:-4]) not in data['id'].tolist():
    images.drop(images[images['filename'].index == i].index, inplace=True)
images
# Out:
#         filename                                               link
# 0      15970.jpg  http://assets.myntassets.com/v1/images/style/p...
# 1      39386.jpg  http://assets.myntassets.com/v1/images/style/p...
# 3      21379.jpg  http://assets.myntassets.com/v1/images/style/p...
# 4      53759.jpg  http://assets.myntassets.com/v1/images/style/p...
# 5       1855.jpg  http://assets.myntassets.com/v1/images/style/p...
# ...          ...                                                ...
# 44436  30614.jpg  http://assets.myntassets.com/v1/images/style/p...
# 44437  13496.jpg  http://assets.myntassets.com/v1/images/style/p...
# 44439  12544.jpg  http://assets.myntassets.com/v1/images/style/p...
# 44440  42234.jpg  http://assets.myntassets.com/v1/images/style/p...
# 44443  18842.jpg  http://assets.myntassets.com/v1/images/style/p...
#
# [18096 rows x 2 columns]

# %%
print(images['filename'].tolist())
print(os.listdir('data\images'))
# Out:
# ['15970.jpg', '39386.jpg', '21379.jpg', '53759.jpg', '1855.jpg', '30805.jpg', '26960.jpg', '12369.jpg', '42419.jpg', '13089.jpg', '7990.jpg', '37812.jpg', '4729.jpg', '56825.jpg', '20099.jpg', '3954.jpg', '28690.jpg', '8580.jpg', '18005.jpg', '9452.jpg', '45856.jpg', '5891.jpg', '38630.jpg', '4943.jpg', '10866.jpg', '15528.jpg', '54924.jpg', '9660.jpg', '2288.jpg', '23876.jpg', '18237.jpg', '49653.jpg', '13419.jpg', '58513.jpg', '52029.jpg', '5865.jpg', '29584.jpg', '28456.jpg', '34009.jpg', '9694.jpg', '15984.jpg', '59297.jpg', '27846.jpg', '26994.jpg', '54588.jpg', '8322.jpg', '7158.jpg', '19547.jpg', '7964.jpg', '16392.jpg', '51455.jpg', '17240.jpg', '6617.jpg', '3365.jpg', '10065.jpg', '5092.jpg', '10859.jpg', '10257.jpg', '24062.jpg', '11385.jpg', '22395.jpg', '31782.jpg', '12500.jpg', '30650.jpg', '32563.jpg', '40143.jpg', '24406.jpg', '21174.jpg', '15341.jpg', '14293.jpg', '6041.jpg', '23623.jpg', '9835.jpg', '7193.jpg', '27283.jpg', '3533.jpg', '12164.jpg', '17624.jpg', '4715
# ...

# %%
import os
for file in os.listdir('data\images'):
    if file not in images['filename'].tolist():
        path = 'data\images\\'+str(file)
        os.remove(path)

# %%
print(len(os.listdir('data\images')))
# Out:
# 18090

# %%
grouped = data.groupby(data.subCategory)
data_topwear = grouped.get_group("Topwear")
data_topwear
# Out:
#           id subCategory articleType   usage
# 0      15970     Topwear      Shirts  Casual
# 4      53759     Topwear     Tshirts  Casual
# 5       1855     Topwear     Tshirts  Casual
# 6      30805     Topwear      Shirts  Ethnic
# 7      26960     Topwear      Shirts  Casual
# ...      ...         ...         ...     ...
# 44414  30614     Topwear     Tshirts  Sports
# 44415  13496     Topwear     Tshirts  Casual
# 44417  12544     Topwear     Tshirts  Casual
# 44418  42234     Topwear        Tops  Casual
# 44421  18842     Topwear     Tshirts  Casual
#
# [15402 rows x 4 columns]

# %%
grouped = data.groupby(data.subCategory)
data_bottomwear = grouped.get_group("Bottomwear")
data_bottomwear
n = data_bottomwear.id.values
n.tolist()
# Out:
# [39386,
#  21379,
#  18005,
#  54924,
#  28456,
#  26994,
#  10257,
#  32563,
#  15341,
#  7193,
#  17624,
#  47154,
#  13284,
#  26163,
#  40371,
#  34204,
#  16508,
#  57138,
#  26993,
#  13248,
#  51499,
#  7709,
#  28451,
#  49654,
#  11349,
#  54923,
#  16198,
#  12538,
#  18002,
#  1638,
#  32903,
#  56822,
#  39381,
#  34203,
#  27614,
#  27426,
#  11520,
#  32590,
#  47153,
#  17623,
#  26164,
#  32564,
#  34693,
#  12163,
#  1607,
#  23072,
#  16368,
#  10259,
#  31111,
#  27622,
#  11340,
#  28458,
#  23044,
#  30453,
#  39388,
#  26152,
#  12155,
#  29780,
#  28460,
#  23088,
#  53750,
#  26155,
#  23043,
#  10261,
#  7707,
#  51497,
#  27417,
#  27625,
#  11347,
#  16506,
#  57136,
#  31116,
#  13246,
#  15111,
#  44581,
#  4774,
#  14695,
#  3909,
#  51605,
#  21586,
#  34054,
#  5004,
#  33271,
#  27027,
#  50949,
#  41007,
#  27215,
#  56847,
#  29176,
#  48387,
#  50378,
#  39122,
#  46813,
#  27018,
#  30893,
#  34259,
#  58571,
#  44912,
#  20037,
#  4787,
# ...

# %%
grouped = data.groupby(data.subCategory)
data_topwear = grouped.get_group("Topwear")
data_topwear
m = data_topwear.id.values
m.tolist()
# Out:
# [15970,
#  53759,
#  1855,
#  30805,
#  26960,
#  12369,
#  42419,
#  13089,
#  7990,
#  37812,
#  4729,
#  56825,
#  20099,
#  3954,
#  28690,
#  8580,
#  9452,
#  45856,
#  5891,
#  38630,
#  4943,
#  10866,
#  15528,
#  9660,
#  2288,
#  23876,
#  18237,
#  49653,
#  13419,
#  58513,
#  52029,
#  5865,
#  29584,
#  34009,
#  9694,
#  15984,
#  59297,
#  27846,
#  54588,
#  8322,
#  7158,
#  19547,
#  7964,
#  16392,
#  51455,
#  17240,
#  6617,
#  3365,
#  10065,
#  5092,
#  10859,
#  24062,
#  11385,
#  22395,
#  31782,
#  12500,
#  30650,
#  40143,
#  24406,
#  21174,
#  14293,
#  6041,
#  23623,
#  9835,
#  27283,
#  3533,
#  12164,
#  3701,
#  42426,
#  10401,
#  37223,
#  53766,
#  25520,
#  32597,
#  57100,
#  50325,
#  16530,
#  7167,
#  46240,
#  27277,
#  6889,
#  31312,
#  12190,
#  19578,
#  27879,
#  6287,
#  7355,
#  43500,
#  13270,
#  31120,
#  11527,
#  40385,
#  15187,
#  14055,
#  20260,
#  28469,
#  34036,
#  8779,
#  2243,
#  33213,
#  39729,
#  11143,
# ...

# %%
import os
for file in os.listdir(r'C:\Users\Nickv\Coding\Python\Linear\data\Clothes\Bottomwear'):
    if int(file[:-4]) not in n.tolist():
        path = r'C:\Users\Nickv\Coding\Python\Linear\data\Clothes\Bottomwear\\'+str(file)
        os.remove(path)

# %%
for file in os.listdir(r'C:\Users\Nickv\Coding\Python\Linear\data\Clothes\Topwear'):
    if int(file[:-4]) not in m.tolist():
        path = r'C:\Users\Nickv\Coding\Python\Linear\data\Clothes\Topwear\\'+str(file)
        os.remove(path)

# %%
print(len(os.listdir(r'C:\Users\Nickv\Coding\Python\Linear\data\Clothes\Bottomwear')))
print(len(os.listdir(r'C:\Users\Nickv\Coding\Python\Linear\data\Clothes\Topwear')))
# Out:
# 2693
# 15397
